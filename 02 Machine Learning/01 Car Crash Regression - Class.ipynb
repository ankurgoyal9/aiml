# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=sns.load_dataset("car_crashes")
data.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [markdown]
# #### Exploring data

# %%
# describe, info, tail, missing values, shape , columns

# %%
data.tail(2)
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 49      106.62     WI
# 50      122.04     WY

# %%
data.shape
# Out:
# (51, 8)

# %%
data.describe()
# Out:
#            total   speeding    alcohol  not_distracted  no_previous  \
# count  51.000000  51.000000  51.000000       51.000000    51.000000
# mean   15.790196   4.998196   4.886784       13.573176    14.004882
# std     4.122002   2.017747   1.729133        4.508977     3.764672
# min     5.900000   1.792000   1.593000        1.760000     5.900000
# 25%    12.750000   3.766500   3.894000       10.478000    11.348000
# 50%    15.600000   4.608000   4.554000       13.857000    13.775000
# 75%    18.500000   6.439000   5.604000       16.140000    16.755000
# max    23.900000   9.450000  10.038000       23.661000    21.280000
#
#        ins_premium  ins_losses
# count    51.000000   51.000000
# mean    886.957647  134.493137
# std     178.296285   24.835922
# min     641.960000   82.750000
# 25%     768.430000  114.645000
# 50%     858.970000  136.050000
# 75%    1007.945000  151.870000
# max    1301.520000  194.780000

# %%
data.describe().T
# Out:
#                 count        mean         std      min       25%      50%  \
# total            51.0   15.790196    4.122002    5.900   12.7500   15.600
# speeding         51.0    4.998196    2.017747    1.792    3.7665    4.608
# alcohol          51.0    4.886784    1.729133    1.593    3.8940    4.554
# not_distracted   51.0   13.573176    4.508977    1.760   10.4780   13.857
# no_previous      51.0   14.004882    3.764672    5.900   11.3480   13.775
# ins_premium      51.0  886.957647  178.296285  641.960  768.4300  858.970
# ins_losses       51.0  134.493137   24.835922   82.750  114.6450  136.050
#
#                      75%       max
# total             18.500    23.900
# speeding           6.439     9.450
# alcohol            5.604    10.038
# not_distracted    16.140    23.661
# no_previous       16.755    21.280
# ins_premium     1007.945  1301.520
# ins_losses       151.870   194.780

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
data.isnull().sum()
# Out:
# total             0
# speeding          0
# alcohol           0
# not_distracted    0
# no_previous       0
# ins_premium       0
# ins_losses        0
# abbrev            0
# dtype: int64

# %%
data.shape
# Out:
# (51, 8)

# %%
data.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses', 'abbrev'],
#       dtype='object')

# %% [markdown]
# Do we have any repeatation of same state

# %%
data.abbrev.unique()
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA',
#        'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA',
#        'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY',
#        'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY'], dtype=object)

# %%
len(data.abbrev.unique())  # no repetation of state
# Out:
# 51

# %%
data.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses', 'abbrev'],
#       dtype='object')

# %%
data.columns[:-1]
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses'],
#       dtype='object')

# %%
#plt.figure(figsize=(20,10))  #temp not working 
data.drop(columns="abbrev").plot(kind="box",subplots=True,figsize=(20,5))
plt.show()

# %%
#data.loc[[:,:-1]]

# %%
#data.loc[-1:]

# %%
sns.scatterplot(x="alcohol",y="total",data=data)
plt.show()

# %%
#data.iloc[:,:-1]

# %%
data.alcohol[data.alcohol>8]
# Out:
# 26     9.416
# 34    10.038
# 40     9.799
# Name: alcohol, dtype: float64

# %%
data[data.alcohol>8]
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 26   21.4     8.346    9.416          17.976       18.190       816.21
# 34   23.9     5.497   10.038          23.661       20.554       688.75
# 40   23.9     9.082    9.799          22.944       19.359       858.97
#
#     ins_losses abbrev
# 26       85.15     MT
# 34      109.72     ND
# 40      116.29     SC

# %%
#data[data.alcohol>8].T

# %%
data.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
data.drop(columns="abbrev").corr()
# Out:
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# total             -0.199702   -0.036011
# speeding          -0.077675   -0.065928
# alcohol           -0.170612   -0.112547
# not_distracted    -0.174856   -0.075970
# no_previous       -0.156895   -0.006359
# ins_premium        1.000000    0.623116
# ins_losses         0.623116    1.000000

# %%
sns.heatmap(data.drop(columns="abbrev").corr(),annot=True,vmin=-1)
plt.show()

# %%
data.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses', 'abbrev'],
#       dtype='object')

# %%
data.drop(columns=['ins_premium', 'ins_losses', 'abbrev'],inplace=True)# RUN ONLY ONCE

# %%
data.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous
# 0   18.8     7.332    5.640          18.048       15.040
# 1   18.1     7.421    4.525          16.290       17.014
# 2   18.6     6.510    5.208          15.624       17.856
# 3   22.4     4.032    5.824          21.056       21.280
# 4   12.0     4.200    3.360          10.920       10.680

# %%
from sklearn.model_selection import train_test_split

# %%
# x=data.drop(columns="total")
# Y=data.total

# %%
x,xt,y,yt=train_test_split(data.drop(columns="total"),
                           data.total,
                          random_state=40,
                          test_size=0.1)

# %%
x
# Out:
#     speeding  alcohol  not_distracted  no_previous
# 21     1.886    2.870           7.134        6.560
# 4      4.200    3.360          10.920       10.680
# 11     9.450    7.175          14.350       15.225
# 2      6.510    5.208          15.624       17.856
# 16     4.806    4.272          13.706       15.130
# 36     6.368    5.771          18.308       18.706
# 23     2.208    2.784           8.448        8.448
# 42     4.095    5.655          15.990       15.795
# 45     4.080    4.080          13.056       12.920
# 47     4.452    3.498           8.692        9.116
# 24     2.640    5.456           1.760       17.600
# 33     6.552    5.208          15.792       13.608
# 18     7.175    6.765          14.965       20.090
# 5      5.032    3.808          10.744       12.920
# 13     4.608    4.352          12.032       12.288
# 40     9.082    9.799          22.944       19.359
# 17     4.066    4.922          16.692       16.264
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=

# %%
lr.fit(x,y) # Training on 90% data x,y
# Out:
# LinearRegression()

# %%
result=lr.predict(xt) # prdict 10% of independent data xt= result-10% predicted yt_hat

# %%
result
# Out:
# array([11.28503683, 25.26294998, 17.23279432, 11.15026549, 12.70561642,
#        17.53221665])

# %%
yt-result  # no required just a RnD
# Out:
# 29    0.314963
# 34   -1.362950
# 50    0.167206
# 39   -0.050265
# 46   -0.005616
# 0     1.267783
# Name: total, dtype: float64

# %% [markdown]
# Scroe should be close to 1 and away from zero

# %%
lr.score(xt,yt)*100
# Out:
# 97.1567884671361

# %%
from sklearn.metrics import r2_score

# %%
r2_score(yt,result)
# Out:
# 0.971567884671361
